# %% [markdown]
# # KLIB

# %%
import klib
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# * Data Visualization

# %%
# returns a visualization of the number and frequency of categorical features
klib.cat_plot(df)

# Here the lines refers to the null values in the particular column
# Out:
# GridSpec(6, 5)

# %%
# returns a color-encoded correlation matrix
klib.corr_mat(df)
# Out:
# <style type="text/css">
# #T_829d8_row0_col0, #T_829d8_row0_col3, #T_829d8_row0_col6, #T_829d8_row1_col1, #T_829d8_row1_col5, #T_829d8_row1_col6, #T_829d8_row2_col2, #T_829d8_row2_col4, #T_829d8_row2_col5, #T_829d8_row3_col0, #T_829d8_row3_col3, #T_829d8_row3_col6, #T_829d8_row4_col2, #T_829d8_row4_col4, #T_829d8_row4_col5, #T_829d8_row4_col6, #T_829d8_row5_col1, #T_829d8_row5_col2, #T_829d8_row5_col4, #T_829d8_row5_col5, #T_829d8_row5_col6, #T_829d8_row6_col0, #T_829d8_row6_col1, #T_829d8_row6_col3, #T_829d8_row6_col4, #T_829d8_row6_col5, #T_829d8_row6_col6 {
#   color: None;
# }
# #T_829d8_row0_col1, #T_829d8_row0_col2, #T_829d8_row0_col4, #T_829d8_row0_col5, #T_829d8_row1_col0, #T_829d8_row1_col2, #T_829d8_row1_col3, #T_829d8_row1_col4, #T_829d8_row2_col0, #T_829d8_row2_col1, #T_829d8_row2_col3, #T_829d8_row2_col6, #T_829d8_row3_col1, #T_829d8_row3_col2, #T_829d8_row3_col4, #T_829d8_row3_col5, #T_829d8_row4_col0, #T_829d8_row4_col1, #T_829d8_row4_col3, #T_829d8_row5_col0, #T_829d8_row5_col3, #T_829d8_row6_col2 {
#   color: #FF3344;
# }
# </style>
# <table id="T_829d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_829d8_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_829d8_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_829d8_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_829d8_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_829d8_level0_col4" class="col_heading level0 col4" >SibSp</th>
#       <th id="T_829d8_level0_col5" class="col_heading level0 col5" >Parch</th>
#       <th id="T_829d8_level0_col6" class="col_heading level0 col6" >Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_829d8_level0_row0" class="row_heading level0 row0" >PassengerId</th>
#       <td id="T_829d8_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_829d8_row0_col1" class="data row0 col1" >-0.01</td>
#       <td id="T_829d8_row0_col2" class="data row0 col2" >-0.04</td>
#       <td id="T_829d8_row0_col3" class="data row0 col3" >0.04</td>
#       <td id="T_829d8_row0_col4" class="data row0 col4" >-0.06</td>
#       <td id="T_829d8_row0_col5" class="data row0 col5" >-0.00</td>
#       <td id="T_829d8_row0_col6" class="data row0 col6" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_829d8_level0_row1" class="row_heading level0 row1" >Survived</th>
#       <td id="T_829d8_row1_col0" class="data row1 col0" >-0.01</td>
#       <td id="T_829d8_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_829d8_row1_col2" class="data row1 col2" >-0.34</td>
#       <td id="T_829d8_row1_col3" class="data row1 col3" >-0.08</td>
#       <td id="T_829d8_row1_col4" class="data row1 col4" >-0.04</td>
#       <td id="T_829d8_row1_col5" class="data row1 col5" >0.08</td>
#       <td id="T_829d8_row1_col6" class="data row1 col6" >0.26</td>
#     </tr>
#     <tr>
#       <th id="T_829d8_level0_row2" class="row_heading level0 row2" >Pclass</th>
#       <td id="T_829d8_row2_col0" class="data row2 col0" >-0.04</td>
#       <td id="T_829d8_row2_col1" class="data row2 col1" >-0.34</td>
#       <td id="T_829d8_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_829d8_row2_col3" class="data row2 col3" >-0.37</td>
#       <td id="T_829d8_row2_col4" class="data row2 col4" >0.08</td>
#       <td id="T_829d8_row2_col5" class="data row2 col5" >0.02</td>
#       <td id="T_829d8_row2_col6" class="data row2 col6" >-0.55</td>
#     </tr>
#     <tr>
#       <th id="T_829d8_level0_row3" class="row_heading level0 row3" >Age</th>
#       <td id="T_829d8_row3_col0" class="data row3 col0" >0.04</td>
#       <td id="T_829d8_row3_col1" class="data row3 col1" >-0.08</td>
#       <td id="T_829d8_row3_col2" class="data row3 col2" >-0.37</td>
#       <td id="T_829d8_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_829d8_row3_col4" class="data row3 col4" >-0.31</td>
#       <td id="T_829d8_row3_col5" class="data row3 col5" >-0.19</td>
#       <td id="T_829d8_row3_col6" class="data row3 col6" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_829d8_level0_row4" class="row_heading level0 row4" >SibSp</th>
#       <td id="T_829d8_row4_col0" class="data row4 col0" >-0.06</td>
#       <td id="T_829d8_row4_col1" class="data row4 col1" >-0.04</td>
#       <td id="T_829d8_row4_col2" class="data row4 col2" >0.08</td>
#       <td id="T_829d8_row4_col3" class="data row4 col3" >-0.31</td>
#       <td id="T_829d8_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_829d8_row4_col5" class="data row4 col5" >0.41</td>
#       <td id="T_829d8_row4_col6" class="data row4 col6" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_829d8_level0_row5" class="row_heading level0 row5" >Parch</th>
#       <td id="T_829d8_row5_col0" class="data row5 col0" >-0.00</td>
#       <td id="T_829d8_row5_col1" class="data row5 col1" >0.08</td>
#       <td id="T_829d8_row5_col2" class="data row5 col2" >0.02</td>
#       <td id="T_829d8_row5_col3" class="data row5 col3" >-0.19</td>
#       <td id="T_829d8_row5_col4" class="data row5 col4" >0.41</td>
#       <td id="T_829d8_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_829d8_row5_col6" class="data row5 col6" >0.22</td>
#     </tr>
#     <tr>
#       <th id="T_829d8_level0_row6" class="row_heading level0 row6" >Fare</th>
#       <td id="T_829d8_row6_col0" class="data row6 col0" >0.01</td>
#       <td id="T_829d8_row6_col1" class="data row6 col1" >0.26</td>
#       <td id="T_829d8_row6_col2" class="data row6 col2" >-0.55</td>
#       <td id="T_829d8_row6_col3" class="data row6 col3" >0.10</td>
#       <td id="T_829d8_row6_col4" class="data row6 col4" >0.16</td>
#       <td id="T_829d8_row6_col5" class="data row6 col5" >0.22</td>
#       <td id="T_829d8_row6_col6" class="data row6 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# returns a color-encoded heatmap, ideal for correlations
klib.corr_plot(df)
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
# returns a distribution plot for every numeric feature
klib.dist_plot(df)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Density'>
